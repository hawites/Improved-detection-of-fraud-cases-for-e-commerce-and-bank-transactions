# %%
import os
import sys
import importlib
sys.path.append(os.path.abspath(".."))
import src.preprocessing
importlib.reload(src.preprocessing)

from src.preprocessing import Preprocessor

# Initialize
pp = Preprocessor(
    fraud_path='../data/Fraud_Data.csv',
    ip_path='../data/IpAddress_to_Country.csv',
    credit_path='../data/creditcard.csv'
)

# Load data
fraud_df, ip_df, credit_df = pp.load_data()

# Preprocess
pp.convert_datetime_columns()
pp.convert_ip_to_int()
pp.drop_creditcard_duplicates()
pp.check_data_integrity()

# Update local variables from the class (if needed for other notebook operations)
fraud_df = pp.fraud_df
ip_df = pp.ip_df
credit_df = pp.credit_df
# Out:
# == FRAUD DATA ==
# Shape: (151112, 12)
# Missing values:
#  user_id           0
# signup_time       0
# purchase_time     0
# purchase_value    0
# device_id         0
# source            0
# browser           0
# sex               0
# age               0
# ip_address        0
# class             0
# ip_int            0
# dtype: int64
# Duplicates: 0
#
# == IP DATA ==
# Shape: (138846, 3)
# Missing values:
#  lower_bound_ip_address    0
# upper_bound_ip_address    0
# country                   0
# dtype: int64
# Duplicates: 0
#
# == CREDIT CARD DATA ==
# Shape: (283726, 31)
# Missing values:
#  Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64
# Duplicates: 0
